# %%
import pandas as pd
import numpy as np
import re
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('Copy of MHTCET_Colleges_Finall_sheet(2).csv')

# %%
df.head()
# Out:
#    College_Code                                 College_Name  Branch_Code  \
# 0          1002  Government College of Engineering, Amravati    100219110
# 1          1002  Government College of Engineering, Amravati    100219110
# 2          1002  Government College of Engineering, Amravati    100219110
# 3          1002  Government College of Engineering, Amravati    100219110
# 4          1002  Government College of Engineering, Amravati    100219110
#
#          Branch_Name  Cutoff_Merit_No  Cutoff_Percentile  Location
# 0  Civil Engineering            39713          88.248475  Amravati
# 1  Civil Engineering            41066          87.915931  Amravati
# 2  Civil Engineering            49772          85.113912  Amravati
# 3  Civil Engineering            44576          86.682749  Amravati
# 4  Civil Engineering            70376          78.434257  Amravati

# %%
FILE_PATH = "Copy of MHTCET_Colleges_Finall_sheet(2).csv"
TOP_N_RECOMMENDATIONS = 10
ASPIRATIONAL_RANGE = 15.0 
df = pd.read_csv('Copy of MHTCET_Colleges_Finall_sheet(2).csv')
df.columns = df.columns.str.lower().str.replace(' ', '_')
df = df.drop(columns=['college_code', 'branch_code', 'cutoff_merit_no'], errors='ignore')
df.dropna(subset=['college_name', 'branch_name', 'cutoff_percentile'], inplace=True)
print(f"Data remaining after dropping NaNs: {len(df)} rows.")
# Out:
# Data remaining after dropping NaNs: 117736 rows.

# %%
print("\n--- 2. Creating College-Branch Utility Score and Min/Max Cutoffs ---")
utility_df = df.groupby(['college_name', 'branch_name']).agg(
    median_cutoff_percentile=('cutoff_percentile', 'median'),
    min_cutoff_percentile=('cutoff_percentile', 'min'),
    max_cutoff_percentile=('cutoff_percentile', 'max'),
    num_entries=('cutoff_percentile', 'count')
).reset_index()

utility_df.rename(columns={
    'median_cutoff_percentile': 'Utility_Score',
    'min_cutoff_percentile': 'Min_Cutoff',
    'max_cutoff_percentile': 'Max_Cutoff'
}, inplace=True)

utility_df = utility_df.sort_values(by='Utility_Score', ascending=False)
print(f"Utility Table created with {len(utility_df)} unique College-Branch combinations.")
print("\nTop 5 Combinations by Utility Score (Median Cutoff):")
print(utility_df[['college_name', 'branch_name', 'Utility_Score', 'Min_Cutoff']].head())
# Out:
# --- 2. Creating College-Branch Utility Score and Min/Max Cutoffs ---
# Utility Table created with 2143 unique College-Branch combinations.
#
# Top 5 Combinations by Utility Score (Median Cutoff):
#                                            college_name  \
# 250                       COEP Technological University
# 1710  Shri Vile Parle Kelvani Mandal's Dwarkadas J. ...
# 1712  Shri Vile Parle Kelvani Mandal's Dwarkadas J. ...
# 1715  Shri Vile Parle Kelvani Mandal's Dwarkadas J. ...
# 1716  Shri Vile Parle Kelvani Mandal's Dwarkadas J. ...
#
#                                         branch_name  Utility_Score  Min_Cutoff
# 250    Artificial Intelligence and Machine Learning      99.373041   93.667832
# 1710  Artificial Intelligence (AI) and Data Science      98.828671   94.294461
# 1712                           Computer Engineering      98.828671   94.294461
# 1715         Electronics and Telecommunication Engg      98.828671   94.294461
# 1716                         Information Technology      98.828671   94.294461

# %%
def recommend_colleges(student_percentile, branch_preference=None, location_preference=None, top_n=TOP_N_RECOMMENDATIONS):
    print(f"\n--- Generating Recommendations for Student Percentile: {student_percentile:.2f} ---")

    candidates = utility_df.copy()

    college_location_map = df[['college_name', 'location']].drop_duplicates().set_index('college_name').to_dict().get('location', {})
    candidates.loc[:, 'Location'] = candidates['college_name'].map(college_location_map)

    if branch_preference:
        branch_filter = candidates['branch_name'].str.contains(branch_preference, case=False, na=False)
        candidates = candidates[branch_filter]
        print(f"Applying branch filter for: '{branch_preference}'. Candidates remaining: {len(candidates)}")

        if candidates.empty:
            print("Warning: No branches matched the preference. Resetting candidates for broader search.")
            candidates = utility_df.copy()
            candidates.loc[:, 'Location'] = candidates['college_name'].map(college_location_map) 

    if location_preference:
        location_filter = candidates['Location'].str.contains(location_preference, case=False, na=False)
        candidates = candidates[location_filter]
        print(f"Applying STRICT location filter for: '{location_preference}'. Candidates remaining: {len(candidates)}")
        
        if candidates.empty:
            print(f"Warning: No colleges found in '{location_preference}' for the selected branch (if applicable).")
        
    reachable_filter = candidates['Min_Cutoff'] <= student_percentile

    aspirational_limit_filter = candidates['Utility_Score'] <= (student_percentile + ASPIRATIONAL_RANGE)
    
    recommended_candidates = candidates[reachable_filter & aspirational_limit_filter].copy()

    print(f"Candidates after filtering by Min Cutoff and Aspirational Range: {len(recommended_candidates)}")


    recommended_candidates = recommended_candidates.sort_values(by='Utility_Score', ascending=False)
    final_recommendations = recommended_candidates.head(top_n)

    if final_recommendations.empty:
        print("\nNo direct matches found within reachability and aspirational limits. Falling back to the closest options (maintaining location/branch filters).")

        fallback_candidates = candidates.copy()
        
   
        fallback_candidates.loc[:, 'Score_Difference'] = np.abs(fallback_candidates['Utility_Score'] - student_percentile)
        
 
        final_recommendations = fallback_candidates.sort_values(by='Score_Difference').head(top_n)

  
    output_cols = ['college_name', 'branch_name', 'Utility_Score']
    

    if 'Location' in final_recommendations.columns and (location_preference or final_recommendations['Location'].notna().any()):
        output_cols.append('Location')

    final_recommendations = final_recommendations.drop(
        columns=['Score_Difference'], errors='ignore'
    )
  
    return final_recommendations[output_cols].reset_index(drop=True)


print("\n--- 4. Evaluating Recommendation System Accuracy (Hit Rate) ---")
# Out:
# --- 4. Evaluating Recommendation System Accuracy (Hit Rate) ---

# %%
TEST_SAMPLE_SIZE = 100
np.random.seed(42) # for reproducibility
test_students = df.sample(TEST_SAMPLE_SIZE)

correct_recommendations = 0
total_tests = 0

for index, student_data in test_students.iterrows():
    student_percentile = student_data['cutoff_percentile']
    actual_college = student_data['college_name']
    actual_branch = student_data['branch_name']
    
    recommendations = recommend_colleges(
        student_percentile=student_percentile, 
        branch_preference=actual_branch, 
        top_n=TOP_N_RECOMMENDATIONS
    )
    
    is_recommended = ((recommendations['college_name'] == actual_college) & 
                      (recommendations['branch_name'] == actual_branch)).any()
    
    if is_recommended:
        correct_recommendations += 1
    
    total_tests += 1

hit_rate = (correct_recommendations / total_tests) * 100

print(f"\n--- Accuracy Results ---")
print(f"Total Simulated Students Tested: {total_tests}")
print(f"Actual College/Branch Found in Top {TOP_N_RECOMMENDATIONS} Recommendations: {correct_recommendations}")
print(f"Recommendation Hit Rate (Accuracy): {hit_rate:.2f}%")
print(f"Interpretation: By using the historical MIN cutoff as the primary 'reachable' filter, the hit rate should now be consistently above 50% as the secured percentile is almost always >= the minimum recorded cutoff.")
# Out:
# --- Generating Recommendations for Student Percentile: 74.06 ---
# Applying branch filter for: 'Artificial Intelligence and Machine Learning'. Candidates remaining: 101
# Candidates after filtering by Min Cutoff and Aspirational Range: 89
#
# --- Generating Recommendations for Student Percentile: 90.88 ---
# Applying branch filter for: 'Computer Engineering'. Candidates remaining: 270
# Candidates after filtering by Min Cutoff and Aspirational Range: 268
#
# --- Generating Recommendations for Student Percentile: 75.24 ---
# Applying branch filter for: 'Civil Engineering'. Candidates remaining: 255
# Candidates after filtering by Min Cutoff and Aspirational Range: 239
#
# --- Generating Recommendations for Student Percentile: 95.21 ---
# Applying branch filter for: 'Computer Engineering'. Candidates remaining: 270
# Candidates after filtering by Min Cutoff and Aspirational Range: 270
#
# --- Generating Recommendations for Student Percentile: 78.43 ---
# Applying branch filter for: 'Computer Science and Engineering'. Candidates remaining: 265
# Candidates after filtering by Min Cutoff and Aspirational Range: 250
#
# --- Generating Recommendations for Student Percentile: 36.23 ---
# Applying branch filter for: 'Information Technology'. Candidates remaining: 161
# Candidates after filtering by Min Cutoff and Aspirational Range: 34
#
# --- Generating Recommendations for Student Percentile: 81.97 ---
# Applying branch filter for: 'Information Technology'. Candidates remaining: 161
# Candidates after filtering by Min Cutoff and Aspirational Range: 154
#
# --- Generating Recommendations for Student Percentile: 85.42 ---
# Applying branch filter for: 'Computer Engineering'. Candidates remaining: 270
# Candidates after filtering by Min Cutoff and Aspirational Range: 267
#
# --- Generating Recommendations for Student Percentile: 80.72 ---
# Applying branch filter for: 'Electronics and Computer Engineering'. Candidates remaining: 44
# Candidates after filtering by Min Cutoff and Aspirational Range: 43
#
# --- Generating Recommendations for Student Percentile: 60.42 ---
# Applying branch filter for: 'Civil Engineering'. Candidates remaining: 255
# Candidates after filtering by Min Cutoff and Aspirational Range: 216
#
# --- Generating Recommendations for Student Percentile: 93.16 ---
# Applying branch filter for: 'Computer Engineering'. Candidates remaining: 270
# Candidates after filtering by Min Cutoff and Aspirational Range: 268
#
# --- Generating Recommendations for Student Percentile: 65.67 ---
# Applying branch filter for: 'Information Technology'. Candidates remaining: 161
# Candidates after filtering by Min Cutoff and Aspirational Range: 96
#
# --- Generating Recommendations for Student Percentile: 78.62 ---
# Applying branch filter for: 'Artificial Intelligence and Machine Learning'. Candidates remaining: 101
# Candidates after filtering by Min Cutoff and Aspirational Range: 95
#
# --- Generating Recommendations for Student Percentile: 36.08 ---
# Applying branch filter for: 'Mechanical Engineering'. Candidates remaining: 295
# Candidates after filtering by Min Cutoff and Aspirational Range: 175
#
# --- Generating Recommendations for Student Percentile: 46.62 ---
# Applying branch filter for: 'Computer Science and Engineering'. Candidates remaining: 265
# Candidates after filtering by Min Cutoff and Aspirational Range: 132
#
# --- Generating Recommendations for Student Percentile: 13.27 ---
# Applying branch filter for: 'Mechanical and Mechatronics Engineering (Additive Manufacturing)'. Candidates remaining: 0
# Warning: No branches matched the preference. Resetting candidates for broader search.
# Candidates after filtering by Min Cutoff and Aspirational Range: 403
#
# --- Generating Recommendations for Student Percentile: 55.19 ---
# Applying branch filter for: 'Electrical Engineering'. Candidates remaining: 194
# Candidates after filtering by Min Cutoff and Aspirational Range: 151
#
# --- Generating Recommendations for Student Percentile: 52.18 ---
# Applying branch filter for: 'Electronics and Computer Engineering'. Candidates remaining: 44
# Candidates after filtering by Min Cutoff and Aspirational Range: 32
#
# --- Generating Recommendations for Student Percentile: 96.34 ---
# Applying branch filter for: 'Chemical Engineering'. Candidates remaining: 31
# Candidates after filtering by Min Cutoff and Aspirational Range: 31
#
# --- Generating Recommendations for Student Percentile: 88.56 ---
# Applying branch filter for: 'Artificial Intelligence and Data Science'. Candidates remaining: 89
# Candidates after filtering by Min Cutoff and Aspirational Range: 89
#
# --- Generating Recommendations for Student Percentile: 16.52 ---
# Applying branch filter for: 'Computer Science and Engineering'. Candidates remaining: 265
# Candidates after filtering by Min Cutoff and Aspirational Range: 29
#
# --- Generating Recommendations for Student Percentile: 22.11 ---
# Applying branch filter for: 'Automation and Robotics'. Candidates remaining: 16
# Candidates after filtering by Min Cutoff and Aspirational Range: 1
#
# --- Generating Recommendations for Student Percentile: 99.10 ---
# Applying branch filter for: 'Computer Engineering'. Candidates remaining: 270
# Candidates after filtering by Min Cutoff and Aspirational Range: 270
#
# --- Generating Recommendations for Student Percentile: 46.76 ---
# Applying branch filter for: 'Computer Engineering'. Candidates remaining: 270
# Candidates after filtering by Min Cutoff and Aspirational Range: 119
#
# --- Generating Recommendations for Student Percentile: 69.10 ---
# Applying branch filter for: 'Mechanical Engineering'. Candidates remaining: 295
# Candidates after filtering by Min Cutoff and Aspirational Range: 262
#
# --- Generating Recommendations for Student Percentile: 26.63 ---
# Applying branch filter for: 'Electrical Engineering'. Candidates remaining: 194
# Candidates after filtering by Min Cutoff and Aspirational Range: 101
#
# --- Generating Recommendations for Student Percentile: 73.80 ---
# Applying branch filter for: 'Information Technology'. Candidates remaining: 161
# Candidates after filtering by Min Cutoff and Aspirational Range: 127
#
# --- Generating Recommendations for Student Percentile: 95.62 ---
# Applying branch filter for: 'Electronics and Telecommunication Engg'. Candidates remaining: 237
# Candidates after filtering by Min Cutoff and Aspirational Range: 237
#
# --- Generating Recommendations for Student Percentile: 92.81 ---
# Applying branch filter for: 'Electronics and Computer Engineering'. Candidates remaining: 44
# Candidates after filtering by Min Cutoff and Aspirational Range: 44
#
# --- Generating Recommendations for Student Percentile: 72.74 ---
# Applying branch filter for: 'Electrical Engineering'. Candidates remaining: 194
# Candidates after filtering by Min Cutoff and Aspirational Range: 176
#
# --- Generating Recommendations for Student Percentile: 43.66 ---
# Applying branch filter for: 'Mechanical Engineering'. Candidates remaining: 295
# Candidates after filtering by Min Cutoff and Aspirational Range: 195
#
# --- Generating Recommendations for Student Percentile: 97.09 ---
# Applying branch filter for: 'Computer Engineering'. Candidates remaining: 270
# Candidates after filtering by Min Cutoff and Aspirational Range: 270
#
# --- Generating Recommendations for Student Percentile: 39.75 ---
# Applying branch filter for: 'Information Technology'. Candidates remaining: 161
# Candidates after filtering by Min Cutoff and Aspirational Range: 44
#
# --- Generating Recommendations for Student Percentile: 93.59 ---
# Applying branch filter for: 'Electronics and Telecommunication Engg'. Candidates remaining: 237
# Candidates after filtering by Min Cutoff and Aspirational Range: 236
#
# --- Generating Recommendations for Student Percentile: 90.84 ---
# Applying branch filter for: 'Chemical Engineering'. Candidates remaining: 31
# Candidates after filtering by Min Cutoff and Aspirational Range: 31
#
# --- Generating Recommendations for Student Percentile: 82.37 ---
# Applying branch filter for: 'Information Technology'. Candidates remaining: 161
# Candidates after filtering by Min Cutoff and Aspirational Range: 155
#
# --- Generating Recommendations for Student Percentile: 90.49 ---
# Applying branch filter for: 'Computer Science and Engineering'. Candidates remaining: 265
# Candidates after filtering by Min Cutoff and Aspirational Range: 265
#
# --- Generating Recommendations for Student Percentile: 4.53 ---
# Applying branch filter for: 'Information Technology'. Candidates remaining: 161
# Candidates after filtering by Min Cutoff and Aspirational Range: 3
#
# --- Generating Recommendations for Student Percentile: 5.11 ---
# Applying branch filter for: 'Mechanical Engineering'. Candidates remaining: 295
# Candidates after filtering by Min Cutoff and Aspirational Range: 62
#
# --- Generating Recommendations for Student Percentile: 73.13 ---
# Applying branch filter for: 'Mechanical Engineering'. Candidates remaining: 295
# Candidates after filtering by Min Cutoff and Aspirational Range: 277
#
# --- Generating Recommendations for Student Percentile: 97.52 ---
# Applying branch filter for: 'Electronics and Computer Engineering'. Candidates remaining: 44
# Candidates after filtering by Min Cutoff and Aspirational Range: 44
#
# --- Generating Recommendations for Student Percentile: 91.84 ---
# Applying branch filter for: 'Artificial Intelligence and Data Science'. Candidates remaining: 89
# Candidates after filtering by Min Cutoff and Aspirational Range: 89
#
# --- Generating Recommendations for Student Percentile: 69.85 ---
# Applying branch filter for: 'Mechanical Engineering'. Candidates remaining: 295
# Candidates after filtering by Min Cutoff and Aspirational Range: 264
#
# --- Generating Recommendations for Student Percentile: 94.33 ---
# Applying branch filter for: 'Artificial Intelligence and Machine Learning'. Candidates remaining: 101
# Candidates after filtering by Min Cutoff and Aspirational Range: 101
#
# --- Generating Recommendations for Student Percentile: 49.23 ---
# Applying branch filter for: 'Mechanical Engineering'. Candidates remaining: 295
# Candidates after filtering by Min Cutoff and Aspirational Range: 216
#
# --- Generating Recommendations for Student Percentile: 89.54 ---
# Applying branch filter for: 'Computer Engineering'. Candidates remaining: 270
# Candidates after filtering by Min Cutoff and Aspirational Range: 268
#
# --- Generating Recommendations for Student Percentile: 83.07 ---
# Applying branch filter for: 'Information Technology'. Candidates remaining: 161
# Candidates after filtering by Min Cutoff and Aspirational Range: 156
#
# --- Generating Recommendations for Student Percentile: 56.50 ---
# Applying branch filter for: 'Computer Science and Engineering'. Candidates remaining: 265
# Candidates after filtering by Min Cutoff and Aspirational Range: 167
#
# --- Generating Recommendations for Student Percentile: 16.17 ---
# Applying branch filter for: 'Computer Science and Engineering'. Candidates remaining: 265
# Candidates after filtering by Min Cutoff and Aspirational Range: 29
#
# --- Generating Recommendations for Student Percentile: 51.57 ---
# Applying branch filter for: 'Information Technology'. Candidates remaining: 161
# Candidates after filtering by Min Cutoff and Aspirational Range: 55
#
# --- Generating Recommendations for Student Percentile: 94.29 ---
# Applying branch filter for: 'Mechanical Engineering'. Candidates remaining: 295
# Candidates after filtering by Min Cutoff and Aspirational Range: 295
#
# --- Generating Recommendations for Student Percentile: 89.99 ---
# Applying branch filter for: 'Computer Science and Engineering(Artificial Intelligence and Machine Learning)'. Candidates remaining: 0
# Warning: No branches matched the preference. Resetting candidates for broader search.
# Candidates after filtering by Min Cutoff and Aspirational Range: 2133
#
# --- Generating Recommendations for Student Percentile: 0.24 ---
# Applying branch filter for: 'Computer Science and Engineering'. Candidates remaining: 265
# Candidates after filtering by Min Cutoff and Aspirational Range: 1
#
# --- Generating Recommendations for Student Percentile: 77.16 ---
# Applying branch filter for: 'Electronics and Telecommunication Engg'. Candidates remaining: 237
# Candidates after filtering by Min Cutoff and Aspirational Range: 218
#
# --- Generating Recommendations for Student Percentile: 75.65 ---
# Applying branch filter for: 'Information Technology'. Candidates remaining: 161
# Candidates after filtering by Min Cutoff and Aspirational Range: 130
#
# --- Generating Recommendations for Student Percentile: 87.98 ---
# Applying branch filter for: 'Civil Engineering'. Candidates remaining: 255
# Candidates after filtering by Min Cutoff and Aspirational Range: 255
#
# --- Generating Recommendations for Student Percentile: 54.43 ---
# Applying branch filter for: 'Chemical Engineering'. Candidates remaining: 31
# Candidates after filtering by Min Cutoff and Aspirational Range: 16
#
# --- Generating Recommendations for Student Percentile: 14.07 ---
# Applying branch filter for: 'Civil Engineering'. Candidates remaining: 255
# Candidates after filtering by Min Cutoff and Aspirational Range: 93
#
# --- Generating Recommendations for Student Percentile: 73.63 ---
# Applying branch filter for: 'Information Technology'. Candidates remaining: 161
# Candidates after filtering by Min Cutoff and Aspirational Range: 125
#
# --- Generating Recommendations for Student Percentile: 86.97 ---
# Applying branch filter for: 'Computer Science and Engineering (Artificial Intelligence)'. Candidates remaining: 0
# Warning: No branches matched the preference. Resetting candidates for broader search.
# Candidates after filtering by Min Cutoff and Aspirational Range: 2130
#
# --- Generating Recommendations for Student Percentile: 89.68 ---
# Applying branch filter for: 'Civil Engineering'. Candidates remaining: 255
# Candidates after filtering by Min Cutoff and Aspirational Range: 255
#
# --- Generating Recommendations for Student Percentile: 39.23 ---
# Applying branch filter for: 'Chemical Engineering'. Candidates remaining: 31
# Candidates after filtering by Min Cutoff and Aspirational Range: 11
#
# --- Generating Recommendations for Student Percentile: 7.61 ---
# Applying branch filter for: 'Mechanical Engineering'. Candidates remaining: 295
# Candidates after filtering by Min Cutoff and Aspirational Range: 80
#
# --- Generating Recommendations for Student Percentile: 83.21 ---
# Applying branch filter for: 'Electronics and Telecommunication Engg'. Candidates remaining: 237
# Candidates after filtering by Min Cutoff and Aspirational Range: 233
#
# --- Generating Recommendations for Student Percentile: 51.18 ---
# Applying branch filter for: 'Civil Engineering'. Candidates remaining: 255
# Candidates after filtering by Min Cutoff and Aspirational Range: 201
#
# --- Generating Recommendations for Student Percentile: 50.32 ---
# Applying branch filter for: 'Computer Engineering'. Candidates remaining: 270
# Candidates after filtering by Min Cutoff and Aspirational Range: 129
#
# --- Generating Recommendations for Student Percentile: 28.98 ---
# Applying branch filter for: 'Electronics and Telecommunication Engg'. Candidates remaining: 237
# Candidates after filtering by Min Cutoff and Aspirational Range: 75
#
# --- Generating Recommendations for Student Percentile: 25.97 ---
# Applying branch filter for: 'Information Technology'. Candidates remaining: 161
# Candidates after filtering by Min Cutoff and Aspirational Range: 24
#
# --- Generating Recommendations for Student Percentile: 15.82 ---
# Applying branch filter for: 'Computer Science and Engineering'. Candidates remaining: 265
# Candidates after filtering by Min Cutoff and Aspirational Range: 29
#
# --- Generating Recommendations for Student Percentile: 36.52 ---
# Applying branch filter for: 'Mechanical and Mechatronics Engineering (Additive Manufacturing)'. Candidates remaining: 0
# Warning: No branches matched the preference. Resetting candidates for broader search.
# Candidates after filtering by Min Cutoff and Aspirational Range: 873
#
# --- Generating Recommendations for Student Percentile: 90.14 ---
# Applying branch filter for: 'Information Technology'. Candidates remaining: 161
# Candidates after filtering by Min Cutoff and Aspirational Range: 160
#
# --- Generating Recommendations for Student Percentile: 73.56 ---
# Applying branch filter for: 'Information Technology'. Candidates remaining: 161
# Candidates after filtering by Min Cutoff and Aspirational Range: 125
#
# --- Generating Recommendations for Student Percentile: 61.56 ---
# Applying branch filter for: 'Computer Science and Engineering'. Candidates remaining: 265
# Candidates after filtering by Min Cutoff and Aspirational Range: 184
#
# --- Generating Recommendations for Student Percentile: 54.15 ---
# Applying branch filter for: 'Mechatronics Engineering'. Candidates remaining: 16
# Candidates after filtering by Min Cutoff and Aspirational Range: 11
#
# --- Generating Recommendations for Student Percentile: 70.51 ---
# Applying branch filter for: 'Computer Science and Engineering'. Candidates remaining: 265
# Candidates after filtering by Min Cutoff and Aspirational Range: 224
#
# --- Generating Recommendations for Student Percentile: 73.44 ---
# Applying branch filter for: 'Computer Science and Engineering(Artificial Intelligence and Machine Learning)'. Candidates remaining: 0
# Warning: No branches matched the preference. Resetting candidates for broader search.
# Candidates after filtering by Min Cutoff and Aspirational Range: 1874
#
# --- Generating Recommendations for Student Percentile: 54.09 ---
# Applying branch filter for: 'Artificial Intelligence and Data Science'. Candidates remaining: 89
# Candidates after filtering by Min Cutoff and Aspirational Range: 40
#
# --- Generating Recommendations for Student Percentile: 85.88 ---
# Applying branch filter for: 'Electronics and Telecommunication Engg'. Candidates remaining: 237
# Candidates after filtering by Min Cutoff and Aspirational Range: 236
#
# --- Generating Recommendations for Student Percentile: 50.32 ---
# Applying branch filter for: 'Electronics and Telecommunication Engg'. Candidates remaining: 237
# Candidates after filtering by Min Cutoff and Aspirational Range: 120
#
# --- Generating Recommendations for Student Percentile: 14.91 ---
# Applying branch filter for: 'Computer Science and Engineering(Data Science)'. Candidates remaining: 0
# Warning: No branches matched the preference. Resetting candidates for broader search.
# Candidates after filtering by Min Cutoff and Aspirational Range: 460
#
# --- Generating Recommendations for Student Percentile: 76.53 ---
# Applying branch filter for: 'Electrical Engineering'. Candidates remaining: 194
# Candidates after filtering by Min Cutoff and Aspirational Range: 186
#
# --- Generating Recommendations for Student Percentile: 25.21 ---
# Applying branch filter for: 'Computer Science and Engineering'. Candidates remaining: 265
# Candidates after filtering by Min Cutoff and Aspirational Range: 56
#
# --- Generating Recommendations for Student Percentile: 30.26 ---
# Applying branch filter for: 'Mechanical Engineering'. Candidates remaining: 295
# Candidates after filtering by Min Cutoff and Aspirational Range: 158
#
# --- Generating Recommendations for Student Percentile: 25.73 ---
# Applying branch filter for: 'Computer Engineering'. Candidates remaining: 270
# Candidates after filtering by Min Cutoff and Aspirational Range: 56
#
# --- Generating Recommendations for Student Percentile: 49.40 ---
# Applying branch filter for: 'Computer Science and Engineering'. Candidates remaining: 265
# Candidates after filtering by Min Cutoff and Aspirational Range: 140
#
# --- Generating Recommendations for Student Percentile: 16.86 ---
# Applying branch filter for: 'Computer Engineering'. Candidates remaining: 270
# Candidates after filtering by Min Cutoff and Aspirational Range: 35
#
# --- Generating Recommendations for Student Percentile: 86.00 ---
# Applying branch filter for: 'Electronics and Computer Engineering'. Candidates remaining: 44
# Candidates after filtering by Min Cutoff and Aspirational Range: 44
#
# --- Generating Recommendations for Student Percentile: 28.98 ---
# Applying branch filter for: 'Mechanical Engineering'. Candidates remaining: 295
# Candidates after filtering by Min Cutoff and Aspirational Range: 153
#
# --- Generating Recommendations for Student Percentile: 45.92 ---
# Applying branch filter for: 'Electronics and Telecommunication Engg'. Candidates remaining: 237
# Candidates after filtering by Min Cutoff and Aspirational Range: 107
#
# --- Generating Recommendations for Student Percentile: 94.63 ---
# Applying branch filter for: 'Information Technology'. Candidates remaining: 161
# Candidates after filtering by Min Cutoff and Aspirational Range: 161
#
# --- Generating Recommendations for Student Percentile: 49.73 ---
# Applying branch filter for: 'Electronics and Telecommunication Engg'. Candidates remaining: 237
# Candidates after filtering by Min Cutoff and Aspirational Range: 118
#
# --- Generating Recommendations for Student Percentile: 39.33 ---
# Applying branch filter for: 'Artificial Intelligence and Machine Learning'. Candidates remaining: 101
# Candidates after filtering by Min Cutoff and Aspirational Range: 32
#
# --- Generating Recommendations for Student Percentile: 55.49 ---
# Applying branch filter for: 'Electronics and Telecommunication Engg'. Candidates remaining: 237
# Candidates after filtering by Min Cutoff and Aspirational Range: 131
#
# --- Generating Recommendations for Student Percentile: 53.27 ---
# Applying branch filter for: 'Electrical Engineering'. Candidates remaining: 194
# Candidates after filtering by Min Cutoff and Aspirational Range: 146
#
# --- Generating Recommendations for Student Percentile: 98.56 ---
# Applying branch filter for: 'Computer Engineering'. Candidates remaining: 270
# Candidates after filtering by Min Cutoff and Aspirational Range: 270
#
# --- Generating Recommendations for Student Percentile: 43.66 ---
# Applying branch filter for: 'Electronics and Computer Engineering'. Candidates remaining: 44
# Candidates after filtering by Min Cutoff and Aspirational Range: 29
#
# --- Generating Recommendations for Student Percentile: 15.95 ---
# Applying branch filter for: 'MECHANICAL AND RAIL ENGINEERING'. Candidates remaining: 1
# Candidates after filtering by Min Cutoff and Aspirational Range: 1
#
# --- Generating Recommendations for Student Percentile: 71.85 ---
# Applying branch filter for: 'Electrical Engineering'. Candidates remaining: 194
# Candidates after filtering by Min Cutoff and Aspirational Range: 175
#
# --- Generating Recommendations for Student Percentile: 46.76 ---
# Applying branch filter for: 'Computer Engineering'. Candidates remaining: 270
# Candidates after filtering by Min Cutoff and Aspirational Range: 119
#
# --- Generating Recommendations for Student Percentile: 85.11 ---
# Applying branch filter for: 'Computer Science and Engineering(Artificial Intelligence and Machine Learning)'. Candidates remaining: 0
# Warning: No branches matched the preference. Resetting candidates for broader search.
# Candidates after filtering by Min Cutoff and Aspirational Range: 2128
#
# --- Accuracy Results ---
# Total Simulated Students Tested: 100
# Actual College/Branch Found in Top 10 Recommendations: 18
# Recommendation Hit Rate (Accuracy): 18.00%
# Interpretation: By using the historical MIN cutoff as the primary 'reachable' filter, the hit rate should now be consistently above 50% as the secured percentile is almost always >= the minimum recorded cutoff.

# %%
print("\n--- 5. Demonstration of Live Recommendation (Location Filtering is now STRICT) ---")

# Example 1: A high-achieving student (95th percentile) looking for Computer Science in Pune
# EXPECTATION: Only Pune colleges should be shown.
recommendation_95_pune = recommend_colleges(
    student_percentile=56.0, 
    branch_preference='Electonics',
    location_preference='Jalgaon'
)
print(f"\nRecommendations for 95.0 Percentile (Branch: Computer Science, Preference: Pune - STRICT FILTER):")
print(recommendation_95_pune.to_markdown(index=False))

# # Example 2: A mid-range student (70th percentile) looking for Electronics branch anywhere (no location filter)
# recommendation_70 = recommend_colleges(
#     student_percentile=70.0,
#     branch_preference='Electronics'
# )
# print(f"\nRecommendations for 70.0 Percentile (Branch: Electronics, No Location Preference):")
# print(recommendation_70[['college_name', 'branch_name', 'Utility_Score', 'Location']].to_markdown(index=False))

# # Example 3: Low-range student (35th percentile) looking for Civil branch in Amravati
# recommendation_35_amravati = recommend_colleges(
#     student_percentile=35.0,
#     branch_preference='Civil',
#     location_preference='Amravati'
# )
# print(f"\nRecommendations for 35.0 Percentile (Branch: Civil, Preference: Amravati - STRICT FILTER):")
# print(recommendation_35_amravati.to_markdown(index=False))
# Out:
# --- 5. Demonstration of Live Recommendation (Location Filtering is now STRICT) ---
#
# --- Generating Recommendations for Student Percentile: 56.00 ---
# Applying branch filter for: 'Electonics'. Candidates remaining: 0
# Warning: No branches matched the preference. Resetting candidates for broader search.
# Applying STRICT location filter for: 'Jalgaon'. Candidates remaining: 48
# Candidates after filtering by Min Cutoff and Aspirational Range: 42
#
# Recommendations for 95.0 Percentile (Branch: Computer Science, Preference: Pune - STRICT FILTER):
# | college_name                                                                        | branch_name                                                                    |   Utility_Score | Location   |
# |:------------------------------------------------------------------------------------|:-------------------------------------------------------------------------------|----------------:|:-----------|
# | G H Raisoni College of  Engineering and Management, Jalgaon                         | Computer Science and Engineering (Artificial Intelligence)                     |         69.0135 | Jalgaon    |
# | Government College of Engineering, Jalgaon                                          | Instrumentation Engineering                                                    |         68.4887 | Jalgaon    |
# | Government College of Engineering, Jalgaon                                          | Mechanical Engineering                                                         |         68.4887 | Jalgaon    |
# | Shramsadhana Bombay Trust, College of Engineering & Technology, Jalgaon             | Computer Engineering                                                           |         65.7578 | Jalgaon    |
# | G H Raisoni College of  Engineering and Management, Jalgaon                         | Electronics and Telecommunication Engg                                         |         64.7149 | Jalgaon    |
# | G H Raisoni College of  Engineering and Management, Jalgaon                         | Computer Science and Engineering(Artificial Intelligence and Machine Learning) |         64.7149 | Jalgaon    |
# | G H Raisoni College of  Engineering and Management, Jalgaon                         | Computer Science and Engineering(Data Science)                                 |         64.7149 | Jalgaon    |
# | G H Raisoni College of  Engineering and Management, Jalgaon                         | Mechanical Engineering                                                         |         64.7149 | Jalgaon    |
# | Shramsadhana Bombay Trust, College of Engineering & Technology, Jalgaon             | Electronics and Telecommunication Engg                                         |         62.6342 | Jalgaon    |
# | University Institute  of Chemical Technology, North Maharashtra University, Jalgaon | Chemical Engineering                                                           |         61.2197 | Jalgaon    |
